# %%
import pandas as pd
import numpy as np

data = pd.read_csv('entropy_comparison.csv', header=None)
data = data.values
print(data)
data = np.delete(data, 1, 0)
data = np.delete(data, 1, 0)
#data = np.delete(data, 1, 0)
#data = np.delete(data, 1, 0)
data = np.transpose(data)

text = ""
text +=  "\hline"
text += "\n"
for i,j in enumerate(data):
    for k in j:
        if k == data[i][0]:
            text += str(int(k))
        else:
            text += str(round(k,4))
        if k != data[i][-1]:
            text += " & "
    text += " \\\\ \n"
    text += "\hline"
    text += "\n"

print(text)
# Out:
# [[1.00000000e+01 3.00000000e+01 5.00000000e+01 7.00000000e+01
#   9.00000000e+01 1.10000000e+02 1.30000000e+02 1.50000000e+02
#   1.70000000e+02 1.90000000e+02 2.10000000e+02 2.30000000e+02
#   2.50000000e+02 2.70000000e+02 2.90000000e+02 3.10000000e+02
#   3.30000000e+02 3.50000000e+02]
#  [3.89864282e-01 3.89864282e-01 3.89864282e-01 3.89864282e-01
#   3.89864282e-01 3.89864282e-01 3.89864282e-01 3.89864282e-01
#   3.89864282e-01 3.89864282e-01 3.89864282e-01 3.89864282e-01
#   3.89864282e-01 3.89864282e-01 3.89864282e-01 3.89864282e-01
#   3.89864282e-01 3.89864282e-01]
#  [4.72111696e-01 4.72111696e-01 4.72111696e-01 4.72111696e-01
#   4.72111696e-01 4.72111696e-01 4.72111696e-01 4.72111696e-01
#   4.72111696e-01 4.72111696e-01 4.72111696e-01 4.72111696e-01
#   4.72111696e-01 4.72111696e-01 4.72111696e-01 4.72111696e-01
#   4.72111696e-01 4.72111696e-01]
#  [2.87759042e-01 2.89415054e-01 2.92873823e-01 2.94228138e-01
#   2.95107511e-01 2.97523618e-01 3.01166789e-01 3.06304206e-01
#   3.08469319e-01 3.09129334e-01 3.08401369e-01 3.10505028e-01
#   3.11753646e-01 3.22295518e-01 3.13537441e-01 3.12329360e-01
#   3.11631376e-01 3.17204473e-01]
#  [3.18200723e-01 3.16359775e-01 3.14905869e-01 3.18706450e-01
#   3.19371834e-01 3.20358231e-01 3.22719449e-01 3.24748028e-01
#   3.26297029e-01 3.34866362e-01 3.30599680e-01 3.35417511e-01
#   3.36941604e-01 3.36510649e-01 3.38887426e-01 3.38564562e-01
#   3.43263143e-01 3.40488234e-01]]
# \hline
# 10 & 0.2877590424213222 & 0.3182007227182765 \\
# \hline
# 30 & 0.28941505363581504 & 0.3163597749546261 \\
# \hline
# 50 & 0.292873823300977 & 0.3149058692730078 \\
# \hline
# 70 & 0.2942281380265013 & 0.318706449867434 \\
# \hline
# 90 & 0.29510751052058765 & 0.31937183429547816 \\
# \hline
# 110 & 0.2975236182312654 & 0.32035823125504065 \\
# \hline
# 130 & 0.30116678881152903 & 0.3227194491806338 \\
# \hline
# 150 & 0.3063042062161205 & 0.32474802755391563 \\
# \hline
# 170 & 0.308469319012289 & 0.3262970292518041 \\
# \hline
# 190 & 0.30912933412803495 & 0.3348663619499128 \\
# \hline
# 210 & 0.30840136902803944 & 0.3305996795664238 \\
# \hline
# 230 & 0.3105050283315378 & 0.3354175112812814 \\
# \hline
# 250 & 0.3117536460080763 & 0.33694160350484564 \\
# \hline
# 270 & 0.3222955181365879 & 0.3365106492813668 \\
# \hline
# 290 & 0.313537441063204 & 0.33888742582979525 \\
# \hline
# 310 & 0.3123293600951041 & 0.3385645618266313 \\
# \hline
# 330 & 0.3116313757044518 & 0.3432631427874342 \\
# \hline
# 350 & 0.3172044730846869 & 0.34048823412055834 \\
# \hline
