# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import random
from bokeh.io import export_png
from bokeh.plotting import figure, output_file, show, save

# %%
def show_sample_1d(filename_prefix, sample_index, perplexity):
    if perplexity != None:
        filename_prefix = filename_prefix + str(perplexity) + ".csv"
    data = pd.read_csv(filename_prefix, header=None)
    
    features = data.columns[1:]
    data_features = data[features]
    data_features_np = data_features.values
    
    x = [i for i in range(len(data_features_np[sample_index]))]
    
    #plt.figure(num=None, figsize=(8, 6), dpi=120, facecolor='w', edgecolor='k')
    plt.bar(x, data_features_np[sample_index], color='blue', width=5)
    
    save_to_disk_filename = filename_prefix[:-4] + ".png"
    print(save_to_disk_filename)
    plt.savefig(save_to_disk_filename)
    plt.show()

# %%
sample_index = 19
#show_sample_2d('test_transformed', 22, 28, 1)
#show_sample_2d('test_randomized', 22, 28, 1)
perplexities = [10, 30, 50, 70, 90, 110, 130, 150, 170, 190, 210, 230, 250, 270, 290, 310, 330, 350]
#perplexities = [110]


show_sample_1d('test_transformed.csv', sample_index, None)
show_sample_1d('test_randomized.csv', sample_index, None)

for i in perplexities:
    filename = "test_randomized_js_"
    #show_sample_2d(filename, 22, 28, sample_index)
    show_sample_1d(filename, sample_index, i)
    
for i in perplexities:
    filename = "test_randomized_ecl_"
    #show_sample_2d(filename, 22, 28, sample_index)
    show_sample_1d(filename, sample_index, i)
# Out:
# test_transformed.png
# test_randomized.png
# test_randomized_js_10.png
# test_randomized_js_30.png
# test_randomized_js_50.png
# test_randomized_js_70.png
# test_randomized_js_90.png
# test_randomized_js_110.png
# test_randomized_js_130.png
# test_randomized_js_150.png
# test_randomized_js_170.png
# test_randomized_js_190.png
# test_randomized_js_210.png
# test_randomized_js_230.png
# test_randomized_js_250.png
# test_randomized_js_270.png
# test_randomized_js_290.png
# test_randomized_js_310.png
# test_randomized_js_330.png
# test_randomized_js_350.png
# test_randomized_ecl_10.png
# test_randomized_ecl_30.png
# test_randomized_ecl_50.png
# test_randomized_ecl_70.png
# test_randomized_ecl_90.png
# test_randomized_ecl_110.png
# test_randomized_ecl_130.png
# test_randomized_ecl_150.png
# test_randomized_ecl_170.png
# test_randomized_ecl_190.png
# test_randomized_ecl_210.png
# test_randomized_ecl_230.png
# test_randomized_ecl_250.png
# test_randomized_ecl_270.png
# ...
