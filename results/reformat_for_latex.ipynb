# %%
import pandas as pd
import numpy as np

data = pd.read_csv('accuracy_HAR1D.csv', header=None)
data = data.values
print(data)
data = np.delete(data, 1, 0)
data = np.delete(data, 1, 0)
#data = np.delete(data, 2, 0)
#data = np.delete(data, 3, 0)
data = np.transpose(data)

text = ""
text +=  "\hline"
text += "\n"
for i,j in enumerate(data):
    for k in j:
        if k == data[i][0]:
            text += str(int(k))
        else:
            text += str(float(k))
        if k != data[i][-1]:
            text += " & "
    text += " \\\\ \n"
    text += "\hline"
    text += "\n"

print(text)
# Out:
# [[ 10.          30.          50.          70.          90.
#   110.         130.         150.         170.         190.
#   210.         230.         250.         270.         290.
#   310.         330.         350.        ]
#  [ 95.11        95.11        95.11        95.11        95.11
#    95.11        95.11        95.11        95.11        95.11
#    95.11        95.11        95.11        95.11        95.11
#    95.11        95.11        95.11      ]
#  [ 94.16        94.16        94.16        94.16        94.16
#    94.16        94.16        94.16        94.16        94.16
#    94.16        94.16        94.16        94.16        94.16
#    94.16        94.16        94.16      ]
#  [ 95.51934827  95.65512559  95.96062458  95.65512559  95.99456891
#    95.62118126  95.45145961  95.58723693  95.51934827  95.72301426
#    95.65512559  96.02851324  95.21384929  95.0101833   95.28173795
#    95.38357094  95.51934827  95.24779362]
#  [ 94.84046164  94.87440597  94.80651731  95.34962661  95.28173795
#    95.48540394  94.94229464  95.17990496  95.21384929  95.04412763
#    94.73862865  94.94229464  94.80651731  94.80651731  94.73862865
#    94.90835031  95.04412763  94.84046164]]
# \hline
# 10 & 95.51934827 & 94.84046164 \\
# \hline
# 30 & 95.65512559 & 94.87440597 \\
# \hline
# 50 & 95.96062458 & 94.80651731 \\
# \hline
# 70 & 95.65512559 & 95.34962661 \\
# \hline
# 90 & 95.99456891 & 95.28173795 \\
# \hline
# 110 & 95.62118126 & 95.48540394 \\
# \hline
# 130 & 95.45145961 & 94.94229464 \\
# \hline
# 150 & 95.58723693 & 95.17990496 \\
# \hline
# 170 & 95.51934827 & 95.21384929 \\
# \hline
# 190 & 95.72301426 & 95.04412763 \\
# \hline
# 210 & 95.65512559 & 94.73862865 \\
# \hline
# 230 & 96.02851324 & 94.94229464 \\
# \hline
# 250 & 95.21384929 & 94.80651731 \\
# \hline
# 270 & 95.0101833 & 94.80651731 \\
# \hline
# 290 & 95.28173795 & 94.73862865 \\
# \hline
# 310 & 95.38357094 & 94.90835031 \\
# \hline
# 330 & 95.51934827 & 95.04412763 \\
# \hline
# 350 & 95.24779362 & 94.84046164 \\
# \hline
