# %%
import pandas as pd
import numpy as np

data = pd.read_csv('accuracy_HAR1D.csv', header=None)
data = data.values

for i,j in enumerate(data):
    if i>0:
        data[i] = 100 - data[i]


print(data)
data = np.delete(data, 1, 0)
data = np.delete(data, 1, 0)
data = np.transpose(data)

text = ""
text +=  "\hline"
text += "\n"
for i,j in enumerate(data):
    for k in j:
        if k == data[i][0]:
            text += str(int(k))
        else:
            text += str(round(k,4))
        if k != data[i][-1]:
            text += " & "
    text += " \\\\ \n"
    text += "\hline"
    text += "\n"

print(text)
# Out:
# [[ 10.          30.          50.          70.          90.
#   110.         130.         150.         170.         190.
#   210.         230.         250.         270.         290.
#   310.         330.         350.        ]
#  [  4.89         4.89         4.89         4.89         4.89
#     4.89         4.89         4.89         4.89         4.89
#     4.89         4.89         4.89         4.89         4.89
#     4.89         4.89         4.89      ]
#  [  5.84         5.84         5.84         5.84         5.84
#     5.84         5.84         5.84         5.84         5.84
#     5.84         5.84         5.84         5.84         5.84
#     5.84         5.84         5.84      ]
#  [  4.48065173   4.34487441   4.03937542   4.34487441   4.00543109
#     4.37881874   4.54854039   4.41276307   4.48065173   4.27698574
#     4.34487441   3.97148676   4.78615071   4.9898167    4.71826205
#     4.61642906   4.48065173   4.75220638]
#  [  5.15953836   5.12559403   5.19348269   4.65037339   4.71826205
#     4.51459606   5.05770536   4.82009504   4.78615071   4.95587237
#     5.26137135   5.05770536   5.19348269   5.19348269   5.26137135
#     5.09164969   4.95587237   5.15953836]
#  [  7.56958588   7.63747454   7.60353021   7.63747454   7.8071962
#     8.18058384   7.87508486   7.73930754   7.87508486   8.01086219
#     7.67141887   7.56958588   7.73930754   7.90902919   7.77325187
#     7.84114053   7.73930754   7.73930754]
#  [  7.77325187   7.7053632    7.84114053   8.04480652   7.53564155
#     7.7053632    7.87508486   7.73930754   7.7053632    8.01086219
#     7.67141887   7.87508486   8.14663951   7.63747454   7.84114053
#     7.90902919   8.07875085   7.7053632 ]]
# \hline
# 10 & 4.480651730000005 & 5.159538359999999 & 7.569585880000005 & 7.773251869999996 \\
# \hline
# 30 & 4.344874410000003 & 5.125594030000002 & 7.6374745399999995 & 7.705363199999994 \\
# \hline
# 50 & 4.039375419999999 & 5.193482689999996 & 7.603530210000002 & 7.841140530000004 \\
# \hline
# 70 & 4.344874410000003 & 4.650373389999999 & 7.6374745399999995 & 8.044806519999995 \\
# \hline
# 90 & 4.005431090000002 & 4.718262050000007 & 7.807196200000007 & 7.535641549999994 \\
# \hline
# 110 & 4.37881874 & 4.514596060000002 & 8.180583839999997 & 7.705363199999994 \\
# \hline
# 130 & 4.548540389999999 & 5.05770536 & 7.8750848600000017.875084860000001 \\
# \hline
# 150 & 4.412763069999997 & 4.820095039999998 & 7.7393075399999997.739307539999999 \\
# \hline
# 170 & 4.480651730000005 & 4.786150710000001 & 7.875084860000001 & 7.705363199999994 \\
# \hline
# 190 & 4.276985740000001 & 4.9558723699999945 & 8.0108621899999978.010862189999997 \\
# \hline
# 210 & 4.344874410000003 & 5.2613713500000046 & 7.6714188699999977.671418869999997 \\
# \hline
# 230 & 3.971486760000005 & 5.05770536 & 7.569585880000005 & 7.875084860000001 \\
# \hline
# 250 & 4.786150710000001 & 5.193482689999996 & 7.739307539999999 & 8.14663951 \\
# \hline
# 270 & 4.989816700000006 & 5.193482689999996 & 7.909029189999998 & 7.6374745399999995 \\
# \hline
# 290 & 4.718262050000007 & 5.2613713500000046 & 7.773251869999996 & 7.841140530000004 \\
# \hline
# 310 & 4.6164290600000015 & 5.091649689999997 & 7.841140530000004 & 7.909029189999998 \\
# \hline
# 330 & 4.480651730000005 & 4.9558723699999945 & 7.739307539999999 & 8.078750850000006 \\
# \hline
# 350 & 4.752206380000004 & 5.159538359999999 & 7.739307539999999 & 7.705363199999994 \\
# \hline
